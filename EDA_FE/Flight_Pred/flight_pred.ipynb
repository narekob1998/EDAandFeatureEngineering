# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_excel("Data_Train.xlsx")
df_test = pd.read_excel("Test_set.xlsx")

# %%
df_train.head()
df_train["Additional_Info"] = df_train["Additional_Info"].replace({"No info" : 0})
df_test["Additional_Info"] = df_test["Additional_Info"].replace({"No info" : 0})

# %%
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop               0   3897
# 1    05:50         13:15   7h 25m     2 stops               0   7662
# 2    09:25  04:25 10 Jun      19h     2 stops               0  13882
# 3    18:05         23:30   5h 25m      1 stop               0   6218
# 4    16:50         21:35   4h 45m      1 stop               0  13302

# %%
df_train["Additional_Info"].isna().count()
# Out:
# 10683

# %%
df_train.shape
# Out:
# (10683, 11)

# %%
df_train.drop(["Additional_Info"], axis = 1)
df_test.drop(["Additional_Info"], axis = 1)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop               0   3897
# 1    05:50         13:15   7h 25m     2 stops               0   7662
# 2    09:25  04:25 10 Jun      19h     2 stops               0  13882
# 3    18:05         23:30   5h 25m      1 stop               0   6218
# 4    16:50         21:35   4h 45m      1 stop               0  13302

# %%
df_train["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df_train["Total_Stops"] = df_train["Total_Stops"].replace({"non-stop" : 0, "1 stop" : 1, "2 stops" : 2, "3 stops" : 3, "4 stops" : 4})
df_test["Total_Stops"] = df_test["Total_Stops"].replace({"non-stop" : 0, "1 stop" : 1, "2 stops" : 2, "3 stops" : 3, "4 stops" : 4})

# %%
df_train.head(30)
# Out:
#               Airline Date_of_Journey    Source Destination  \
# 0              IndiGo      24/03/2019  Banglore   New Delhi
# 1           Air India       1/05/2019   Kolkata    Banglore
# 2         Jet Airways       9/06/2019     Delhi      Cochin
# 3              IndiGo      12/05/2019   Kolkata    Banglore
# 4              IndiGo      01/03/2019  Banglore   New Delhi
# 5            SpiceJet      24/06/2019   Kolkata    Banglore
# 6         Jet Airways      12/03/2019  Banglore   New Delhi
# 7         Jet Airways      01/03/2019  Banglore   New Delhi
# 8         Jet Airways      12/03/2019  Banglore   New Delhi
# 9   Multiple carriers      27/05/2019     Delhi      Cochin
# 10          Air India       1/06/2019     Delhi      Cochin
# 11             IndiGo      18/04/2019   Kolkata    Banglore
# 12          Air India      24/06/2019   Chennai     Kolkata
# 13        Jet Airways       9/05/2019   Kolkata    Banglore
# 14             IndiGo      24/04/2019   Kolkata    Banglore
# ...

# %%
final_df = pd.concat([df_train, df_test])

# %%
final_df.head(-10)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2656        Jet Airways      12/05/2019   Kolkata    Banglore
# 2657  Multiple carriers       6/06/2019     Delhi      Cochin
# 2658        Jet Airways      15/06/2019     Delhi      Cochin
# 2659        Jet Airways      15/06/2019     Delhi      Cochin
# 2660          Air India      12/03/2019    Mumbai   Hyderabad
#
#                       Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m          0.0
# ...

# %%
final_df["Total_Stops"] = final_df["Total_Stops"].replace({"non-stop" : 0, "1 stop" : 1, "2 stops" : 2, "3 stops" : 3, "4 stops" : 4, "nan" : 1})

# %%
final_df.head(-10)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2656        Jet Airways      12/05/2019   Kolkata    Banglore
# 2657  Multiple carriers       6/06/2019     Delhi      Cochin
# 2658        Jet Airways      15/06/2019     Delhi      Cochin
# 2659        Jet Airways      15/06/2019     Delhi      Cochin
# 2660          Air India      12/03/2019    Mumbai   Hyderabad
#
#                       Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m          0.0
# ...

# %%
final_df["Day"] = final_df["Date_of_Journey"].str.split("/").str[0]
final_df["Month"] = final_df["Date_of_Journey"].str.split("/").str[1]
final_df["Year"] = final_df["Date_of_Journey"].str.split("/").str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info    Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m          0.0               0   3897.0  24
# 1    05:50         13:15   7h 25m          2.0               0   7662.0   1
# 2    09:25  04:25 10 Jun      19h          2.0               0  13882.0   9
# 3    18:05         23:30   5h 25m          1.0               0   6218.0  12
# 4    16:50         21:35   4h 45m          1.0               0  13302.0  01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
final_df["Day"] = final_df["Day"].astype(int)
final_df["Month"] = final_df["Month"].astype(int)
final_df["Year"] = final_df["Year"].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  float64
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Day              13354 non-null  int64
#  12  Month            13354 non-null  int64
#  13  Year             13354 non-null  int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.5+ MB

# %%
final_df.drop("Date_of_Journey", axis = 1, inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration  Total_Stops Additional_Info    Price  Day  Month  \
# 0  01:10 22 Mar   2h 50m          0.0               0   3897.0   24      3
# 1         13:15   7h 25m          2.0               0   7662.0    1      5
# 2  04:25 10 Jun      19h          2.0               0  13882.0    9      6
# 3         23:30   5h 25m          1.0               0   6218.0   12      5
# 4         21:35   4h 45m          1.0               0  13302.0    1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
final_df["Arrival_Time"] = final_df["Arrival_Time"].str.split(" ").str[0]

# %%
final_df.head(-10)
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2656        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    21:10
# 2657  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
# 2658        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2659        Jet Airways     Delhi      Cochin  DEL → BHO → BOM → COK    05:30
# 2660          Air India    Mumbai   Hyderabad  BOM → GOI → PNQ → HYD    16:50
#
# ...

# %%
final_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Day                   0
# Month                 0
# Year                  0
# dtype: int64

# %%
final_df["Arrival_Hour"] = final_df["Arrival_Time"].str.split(":").str[0]
final_df["Arrival_Min"] = final_df["Arrival_Time"].str.split(":").str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration  Total_Stops Additional_Info    Price  Day  Month  \
# 0        01:10   2h 50m          0.0               0   3897.0   24      3
# 1        13:15   7h 25m          2.0               0   7662.0    1      5
# 2        04:25      19h          2.0               0  13882.0    9      6
# 3        23:30   5h 25m          1.0               0   6218.0   12      5
# 4        21:35   4h 45m          1.0               0  13302.0    1      3
#
#    Year Arrival_Hour Arrival_Min
# 0  2019           01          10
# 1  2019           13          15
# ...

# %%
final_df["Arrival_Hour"] = final_df["Arrival_Hour"].astype(int)
final_df["Arrival_Min"] = final_df["Arrival_Min"].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  float64
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Day              13354 non-null  int64
#  11  Month            13354 non-null  int64
#  12  Year             13354 non-null  int64
#  13  Arrival_Hour     13354 non-null  int64
#  14  Arrival_Min      13354 non-null  int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 1.6+ MB

# %%
final_df.drop("Arrival_Time", axis = 1, inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#    Total_Stops Additional_Info    Price  Day  Month  Year  Arrival_Hour  \
# 0          0.0               0   3897.0   24      3  2019             1
# 1          2.0               0   7662.0    1      5  2019            13
# 2          2.0               0  13882.0    9      6  2019             4
# 3          1.0               0   6218.0   12      5  2019            23
# 4          1.0               0  13302.0    1      3  2019            21
#
#    Arrival_Min
# 0           10
# 1           15
# ...

# %%
final_df["Dep_Hour"] = final_df["Dep_Time"].str.split(":").str[0]
final_df["Dep_Min"] = final_df["Dep_Time"].str.split(":").str[1]

# %%
final_df["Dep_Hour"] = final_df["Dep_Hour"].astype(int)
final_df["Dep_Min"] = final_df["Dep_Min"].astype(int)

# %%
final_df.drop("Dep_Time", axis = 1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Day              13354 non-null  int64
#  9   Month            13354 non-null  int64
#  10  Year             13354 non-null  int64
#  11  Arrival_Hour     13354 non-null  int64
#  12  Arrival_Min      13354 non-null  int64
#  13  Dep_Hour         13354 non-null  int64
#  14  Dep_Min          13354 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 1.6+ MB

# %%
final_df[final_df["Total_Stops"].isnull()]
# Out:
#         Airline Source Destination Route Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m          NaN
#
#      Additional_Info   Price  Day  Month  Year  Arrival_Hour  Arrival_Min  \
# 9039               0  7480.0    6      5  2019             9           25
#
#       Dep_Hour  Dep_Min
# 9039         9       45

# %%
final_df["Duration_Hour"] = final_df["Duration"].str.split(" ").str[0].str.split("h").str[0]

# %%
final_df[final_df["Duration"] == "5m"]
# Out:
#         Airline  Source Destination                  Route Duration  \
# 6474  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       5m
# 2660  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       5m
#
#       Total_Stops Additional_Info    Price  Day  Month  Year  Arrival_Hour  \
# 6474          2.0               0  17327.0    6      3  2019            16
# 2660          2.0               0      NaN   12      3  2019            16
#
#       Arrival_Min  Dep_Hour  Dep_Min Duration_Hour
# 6474           55        16       50            5m
# 2660           55        16       50            5m

# %%
final_df.drop(6474, axis = 0, inplace=True)
final_df.drop(2660, axis = 0, inplace=True)

# %%
final_df["Duration_Hour"] = final_df["Duration_Hour"].astype(int)

# %%
final_df["Duration_Hour"] = final_df["Duration_Hour"]*60

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Day  Month  Year  Arrival_Hour  \
# 0          0.0               0   3897.0   24      3  2019             1
# 1          2.0               0   7662.0    1      5  2019            13
# 2          2.0               0  13882.0    9      6  2019             4
# 3          1.0               0   6218.0   12      5  2019            23
# 4          1.0               0  13302.0    1      3  2019            21
#
#    Arrival_Min  Dep_Hour  Dep_Min  Duration_Hour
# 0           10        22       20            120
# ...

# %%
final_df["Duration_Min"] = final_df["Duration"].str.split(" ").str[1].str.split("m").str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Day  Month  Year  Arrival_Hour  \
# 0          0.0               0   3897.0   24      3  2019             1
# 1          2.0               0   7662.0    1      5  2019            13
# 2          2.0               0  13882.0    9      6  2019             4
# 3          1.0               0   6218.0   12      5  2019            23
# 4          1.0               0  13302.0    1      3  2019            21
#
#    Arrival_Min  Dep_Hour  Dep_Min  Duration_Hour Duration_Min
# ...

# %%
final_df["Duration_Min"].isnull().count()
# Out:
# 13351

# %%
final_df.head(-20)
# Out:
#           Airline    Source Destination                  Route Duration  \
# 0          IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1       Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2     Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3          IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4          IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...           ...       ...         ...                    ...      ...
# 2645  Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   9h 20m
# 2646  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK  29h 20m
# 2647    Air India   Kolkata    Banglore  CCU → GAU → DEL → BLR  16h 10m
# 2648       IndiGo     Delhi      Cochin              DEL → COK   3h 15m
# 2649     SpiceJet  Banglore       Delhi              BLR → DEL   2h 40m
#
#       Total_Stops               Additional_Info    Price  Day  Month  Year  \
# ...

# %%
final_df["Duration_Min"] = final_df["Duration_Min"].fillna(0)

# %%
final_df["Duration_Min"] = final_df[["Duration_Min"]].astype(int)

# %%
final_df["Duration_Hour"] = final_df["Duration_Hour"] + final_df["Duration_Min"]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Day  Month  Year  Arrival_Hour  \
# 0          0.0               0   3897.0   24      3  2019             1
# 1          2.0               0   7662.0    1      5  2019            13
# 2          2.0               0  13882.0    9      6  2019             4
# 3          1.0               0   6218.0   12      5  2019            23
# 4          1.0               0  13302.0    1      3  2019            21
#
#    Arrival_Min  Dep_Hour  Dep_Min  Duration_Hour  Duration_Min
# ...

# %%
final_df.drop("Duration_Min", axis = 1, inplace=True)
final_df.drop("Duration", axis = 1, inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL          1.0
#
#   Additional_Info    Price  Day  Month  Year  Arrival_Hour  Arrival_Min  \
# 0               0   3897.0   24      3  2019             1           10
# 1               0   7662.0    1      5  2019            13           15
# 2               0  13882.0    9      6  2019             4           25
# 3               0   6218.0   12      5  2019            23           30
# 4               0  13302.0    1      3  2019            21           35
#
#    Dep_Hour  Dep_Min  Duration_Hour
# 0        22       20            170
# ...

# %%
final_df.rename(columns = {"Duration_Hour" : "Duration_In_Minutes"},  inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL          1.0
#
#   Additional_Info    Price  Day  Month  Year  Arrival_Hour  Arrival_Min  \
# 0               0   3897.0   24      3  2019             1           10
# 1               0   7662.0    1      5  2019            13           15
# 2               0  13882.0    9      6  2019             4           25
# 3               0   6218.0   12      5  2019            23           30
# 4               0  13302.0    1      3  2019            21           35
#
#    Dep_Hour  Dep_Min  Duration_In_Minutes
# 0        22       20                  170
# ...

# %%
final_df.drop("Route", axis = 1, inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0       IndiGo  Banglore   New Delhi          0.0               0   3897.0
# 1    Air India   Kolkata    Banglore          2.0               0   7662.0
# 2  Jet Airways     Delhi      Cochin          2.0               0  13882.0
# 3       IndiGo   Kolkata    Banglore          1.0               0   6218.0
# 4       IndiGo  Banglore   New Delhi          1.0               0  13302.0
#
#    Day  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   24      3  2019             1           10        22       20
# 1    1      5  2019            13           15         5       50
# 2    9      6  2019             4           25         9       25
# 3   12      5  2019            23           30        18        5
# 4    1      3  2019            21           35        16       50
#
#    Duration_In_Minutes
# 0                  170
# 1                  445
# 2                 1140
# ...

# %%
final_df.dropna(subset = ["Total_Stops"], inplace=True)

# %%
final_df["Total_Stops"] = final_df["Total_Stops"].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13350 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Airline              13350 non-null  object
#  1   Source               13350 non-null  object
#  2   Destination          13350 non-null  object
#  3   Total_Stops          13350 non-null  int64
#  4   Additional_Info      13350 non-null  object
#  5   Price                10680 non-null  float64
#  6   Day                  13350 non-null  int64
#  7   Month                13350 non-null  int64
#  8   Year                 13350 non-null  int64
#  9   Arrival_Hour         13350 non-null  int64
#  10  Arrival_Min          13350 non-null  int64
#  11  Dep_Hour             13350 non-null  int64
#  12  Dep_Min              13350 non-null  int64
#  13  Duration_In_Minutes  13350 non-null  int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 1.5+ MB

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
labelencoder = LabelEncoder()
ohe = OneHotEncoder()

# %%
final_df["Airline"] = labelencoder.fit_transform(final_df["Airline"])
final_df["Source"] = labelencoder.fit_transform(final_df["Source"])
final_df["Destination"] = labelencoder.fit_transform(final_df["Destination"])
# final_df["Additional_Info"] = labelencoder.fit_transform(final_df["Additional_Info"])

# %%
# final_df["Airline"] = ohe.fit_transform(final_df["Airline"])
# final_df["Source"] = ohe.fit_transform(final_df["Source"])
# final_df["Destination"] = ohe.fit_transform(final_df["Destination"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/narekbayramyan/Desktop/EDA_FE/Flight_Pred/flight_pred.ipynb Cell 63 line 1
# ----> <a href='vscode-notebook-cell:/Users/narekbayramyan/Desktop/EDA_FE/Flight_Pred/flight_pred.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> final_df["Airline"] = ohe.fit_transform(final_df["Airline"])
#       <a href='vscode-notebook-cell:/Users/narekbayramyan/Desktop/EDA_FE/Flight_Pred/flight_pred.ipynb#Y120sZmlsZQ%3D%3D?line=1'>2</a> final_df["Source"] = ohe.fit_transform(final_df["Source"])
#       <a href='vscode-notebook-cell:/Users/narekbayramyan/Desktop/EDA_FE/Flight_Pred/flight_pred.ipynb#Y120sZmlsZQ%3D%3D?line=2'>3</a> final_df["Destination"] = ohe.fit_transform(final_df["Destination"])
#
# ...
